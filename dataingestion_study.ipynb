# %%
pip install youtube-transcript-api
# Out:
# ...
#   Using cached defusedxml-0.7.1-py2.py3-none-any.whl.metadata (32 kB)
# ...
#    ---------------------------------------- 0.0/622.3 kB ? eta -:--:--
#    ---------------------------------------- 622.3/622.3 kB 5.8 MB/s eta 0:00:00
# Using cached defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pytube
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_community.document_loaders import YoutubeLoader

video_url = 'https://www.youtube.com/watch?v=LKCVKw9CzFo'
loader = YoutubeLoader(video_id='LKCVKw9CzFo', add_video_info=True)
data = loader.load()
len(data)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File f:\AgenticAI\Workplace\agai_env\Lib\site-packages\pytube\__main__.py:341, in YouTube.title(self)
#     340 try:
# --> 341     self._title = self.vid_info['videoDetails']['title']
#     342 except KeyError:
#     343     # Check_availability will raise the correct exception in most cases
#     344     #  if it doesn't, ask for a report.
#
# KeyError: 'videoDetails'
#
# During handling of the above exception, another exception occurred:
#
# PytubeError                               Traceback (most recent call last)
# Cell In[2], line 5
#       3 video_url = 'https://www.youtube.com/watch?v=LKCVKw9CzFo'
#       4 loader = YoutubeLoader(video_id='LKCVKw9CzFo', add_video_info=True)
# ----> 5 data = loader.load()
#       6 len(data)
#
# ...

# %%
loader = YoutubeLoader.from_youtube_url(
    "https://www.youtube.com/watch?v=QsYGlZkevEg", add_video_info=True
)
loader.load()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File f:\AgenticAI\Workplace\agai_env\Lib\site-packages\pytube\__main__.py:341, in YouTube.title(self)
#     340 try:
# --> 341     self._title = self.vid_info['videoDetails']['title']
#     342 except KeyError:
#     343     # Check_availability will raise the correct exception in most cases
#     344     #  if it doesn't, ask for a report.
#
# KeyError: 'videoDetails'
#
# During handling of the above exception, another exception occurred:
#
# PytubeError                               Traceback (most recent call last)
# Cell In[3], line 4
#       1 loader = YoutubeLoader.from_youtube_url(
#       2     "https://www.youtube.com/watch?v=QsYGlZkevEg", add_video_info=True
#       3 )
# ----> 4 loader.load()
#
# ...

# %%
from langchain_community.document_loaders import UnstructuredEmailLoader

loader = UnstructuredEmailLoader("https://mail.google.com/mail/u/0/#inbox/FMfcgzQZTgQFvfwlbVRckxxcFHGkhGbW")

data = loader.load()

data
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File f:\AgenticAI\Workplace\agai_env\Lib\site-packages\langchain_community\document_loaders\unstructured.py:59, in UnstructuredBaseLoader.__init__(self, mode, post_processors, **unstructured_kwargs)
#      58 try:
# ---> 59     import unstructured  # noqa:F401
#      60 except ImportError:
#
# ModuleNotFoundError: No module named 'unstructured'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 3
#       1 from langchain_community.document_loaders import UnstructuredEmailLoader
# ----> 3 loader = UnstructuredEmailLoader("https://mail.google.com/mail/u/0/#inbox/FMfcgzQZTgQFvfwlbVRckxxcFHGkhGbW")
#       5 data = loader.load()
#       7 data
#
# ...

# %%
## Text Loader

from langchain_community.document_loaders import TextLoader

loader=TextLoader('speech.txt')
loader
