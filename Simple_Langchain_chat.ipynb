# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")
os.environ["LANGCHAIN_TRACING_V2"]="true"
os.environ["LANGCHAIN_PROJECT"]=os.getenv("LANGCHAIN_PROJECT")
os.environ["LANGCHAIN_API_KEY"]=os.getenv("LANGCHAIN_API_KEY")

# %%
from langchain_groq import ChatGroq

# Initialize Groq LLM
llm = ChatGroq(
    model= "llama-3.3-70b-versatile", #"llama-3.1-70b-versatile",  # or "mixtral-8x7b", "gemma2-9b-it", etc.
    temperature=0.7,
    max_tokens=1024,
   
)

print(llm)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from langchain_groq import ChatGroq
#       3 # Initialize Groq LLM
#       4 llm = ChatGroq(
#       5     model= "llama-3.3-70b-versatile", #"llama-3.1-70b-versatile",  # or "mixtral-8x7b", "gemma2-9b-it", etc.
#       6     temperature=0.7,
#       7     max_tokens=1024,
#       8
#       9 )
#
# File f:\AgenticAI\Workplace\agai_env\Lib\site-packages\langchain_groq\__init__.py:1
# ----> 1 from langchain_groq.chat_models import ChatGroq
#       2 from langchain_groq.version import __version__
#       4 __all__ = ["ChatGroq", "__version__"]
#
# File f:\AgenticAI\Workplace\agai_env\Lib\site-packages\langchain_groq\chat_models.py:16
#      11 from langchain_core._api import deprecated
#      12 from langchain_core.callbacks import (
#      13     AsyncCallbackManagerForLLMRun,
#      14     CallbackManagerForLLMRun,
#      15 )
# ---> 16 from langchain_core.language_models import LanguageModelInput
#      17 from langchain_core.language_models.chat_models import (
#      18     BaseChatModel,
#      19     LangSmithParams,
#      20     agenerate_from_stream,
#      21     generate_from_stream,
#      22 )
#      23 from langchain_core.messages import (
#      24     AIMessage,
#      25     AIMessageChunk,
#    (...)
#      39     ToolMessageChunk,
#      40 )
#
# File <frozen importlib._bootstrap>:1412, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File f:\AgenticAI\Workplace\agai_env\Lib\site-packages\langchain_core\language_models\__init__.py:112, in __getattr__(attr_name)
#     110 def __getattr__(attr_name: str) -> object:
#     111     module_name = _dynamic_imports.get(attr_name)
# --> 112     result = import_attr(attr_name, module_name, __spec__.parent)
#     113     globals()[attr_name] = result
#     114     return result
#
# File f:\AgenticAI\Workplace\agai_env\Lib\site-packages\langchain_core\_import_utils.py:36, in import_attr(attr_name, module_name, package)
#      34 else:
#      35     try:
# ---> 36         module = import_module(f".{module_name}", package=package)
#      37     except ModuleNotFoundError as err:
#      38         msg = f"module '{package!r}.{module_name!r}' not found ({err})"
#
# File f:\AgenticAI\Workplace\agai_env\Lib\importlib\__init__.py:90, in import_module(name, package)
#      88             break
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File f:\AgenticAI\Workplace\agai_env\Lib\site-packages\langchain_core\language_models\base.py:44
#      41     from langchain_core.outputs import LLMResult
#      43 try:
# ---> 44     from transformers import GPT2TokenizerFast  # type: ignore[import-not-found]
#      46     _HAS_TRANSFORMERS = True
#      47 except ImportError:
#
# File f:\AgenticAI\Workplace\agai_env\Lib\site-packages\transformers\__init__.py:26
#      23 from typing import TYPE_CHECKING
#      25 # Check the dependencies satisfy the minimal versions required.
# ---> 26 from . import dependency_versions_check
#      27 from .utils import (
#      28     OptionalDependencyNotAvailable,
#      29     _LazyModule,
#    (...)
#      48     logging,
#      49 )
#      52 logger = logging.get_logger(__name__)  # pylint: disable=invalid-name
#
# File f:\AgenticAI\Workplace\agai_env\Lib\site-packages\transformers\dependency_versions_check.py:16
#       1 # Copyright 2020 The HuggingFace Team. All rights reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
#      15 from .dependency_versions_table import deps
# ---> 16 from .utils.versions import require_version, require_version_core
#      19 # define which module versions we always want to check at run time
#      20 # (usually the ones defined in `install_requires` in setup.py)
#      21 #
#      22 # order specific notes:
#      23 # - tqdm must be checked before tokenizers
#      25 pkgs_to_check_at_runtime = [
#      26     "python",
#      27     "tqdm",
#    (...)
#      37     "pyyaml",
#      38 ]
#
# File f:\AgenticAI\Workplace\agai_env\Lib\site-packages\transformers\utils\__init__.py:27
#      25 from .. import __version__
#      26 from .backbone_utils import BackboneConfigMixin, BackboneMixin
# ---> 27 from .chat_template_utils import DocstringParsingException, TypeHintParsingException, get_json_schema
#      28 from .constants import IMAGENET_DEFAULT_MEAN, IMAGENET_DEFAULT_STD, IMAGENET_STANDARD_MEAN, IMAGENET_STANDARD_STD
#      29 from .doc import (
#      30     add_code_sample_docstrings,
#      31     add_end_docstrings,
#    (...)
#      35     replace_return_docstrings,
#      36 )
#
# File f:\AgenticAI\Workplace\agai_env\Lib\site-packages\transformers\utils\chat_template_utils.py:39
#      36     from PIL.Image import Image
#      38 if is_torch_available():
# ---> 39     from torch import Tensor
#      42 BASIC_TYPES = (int, float, str, bool, Any, type(None), ...)
#      43 # Extracts the initial segment of the docstring, containing the function description
#
# File f:\AgenticAI\Workplace\agai_env\Lib\site-packages\torch\__init__.py:274
#     270                     raise err
#     272         kernel32.SetErrorMode(prev_error_mode)
# --> 274     _load_dll_libraries()
#     275     del _load_dll_libraries
#     278 def _preload_cuda_deps(lib_folder: str, lib_name: str) -> None:
#
# File f:\AgenticAI\Workplace\agai_env\Lib\site-packages\torch\__init__.py:250, in _load_dll_libraries()
#     248 is_loaded = False
#     249 if with_load_library_flags:
# --> 250     res = kernel32.LoadLibraryExW(dll, None, 0x00001100)
#     251     last_error = ctypes.get_last_error()
#     252     if res is None and last_error != 126:
#
# KeyboardInterrupt:
